# %%
import pandas as pd

# %%
df =pd.read_csv("autos.csv")
df
# Out:
#      symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0            3  alfa-romero       gas        std             2  convertible
# 1            3  alfa-romero       gas        std             2  convertible
# 2            1  alfa-romero       gas        std             2    hatchback
# 3            2         audi       gas        std             4        sedan
# 4            2         audi       gas        std             4        sedan
# ..         ...          ...       ...        ...           ...          ...
# 188         -1        volvo       gas        std             4        sedan
# 189         -1        volvo       gas      turbo             4        sedan
# 190         -1        volvo       gas        std             4        sedan
# 191         -1        volvo    diesel      turbo             4        sedan
# 192         -1        volvo       gas      turbo             4        sedan
#
# ...

# %%
df.head(8)
# Out:
#    symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0          3  alfa-romero       gas        std             2  convertible
# 1          3  alfa-romero       gas        std             2  convertible
# 2          1  alfa-romero       gas        std             2    hatchback
# 3          2         audi       gas        std             4        sedan
# 4          2         audi       gas        std             4        sedan
# 5          2         audi       gas        std             2        sedan
# 6          1         audi       gas        std             4        sedan
# 7          1         audi       gas        std             4        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# ...

# %%
df.describe(min)
# Out:
#         symboling  num_of_doors  wheel_base      length       width  \
# count  193.000000    193.000000  193.000000  193.000000  193.000000
# mean     0.797927      3.160622   98.923834  174.326425   65.893782
# std      1.235582      0.989583    6.152409   12.478593    2.137795
# min     -2.000000      2.000000   86.600000  141.100000   60.300000
# 25%      0.000000      2.000000   94.500000  166.300000   64.100000
# 50%      1.000000      4.000000   97.000000  173.200000   65.400000
# 75%      2.000000      4.000000  102.400000  184.600000   66.900000
# max      3.000000      4.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  num_of_cylinders  engine_size        bore  \
# count  193.000000   193.000000        193.000000   193.000000  193.000000
# mean    53.869948  2561.507772          4.419689   128.124352    3.330622
# std      2.394770   526.700026          1.023182    41.590452    0.272385
# ...

# %%
type(df[["make","price"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["make","price","fuel_type"]]
# Out:
#             make  price fuel_type
# 0    alfa-romero  13495       gas
# 1    alfa-romero  16500       gas
# 2    alfa-romero  16500       gas
# 3           audi  13950       gas
# 4           audi  17450       gas
# ..           ...    ...       ...
# 188        volvo  16845       gas
# 189        volvo  19045       gas
# 190        volvo  21485       gas
# 191        volvo  22470    diesel
# 192        volvo  22625       gas
#
# [193 rows x 3 columns]

# %%
company = df.groupby('make')
priceDf = company['make','price'].min()
priceDf
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3024\2275013245.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = company['make','price'].min()
#                         make  price
# make
# alfa-romero      alfa-romero  13495
# audi                    audi  13950
# bmw                      bmw  16430
# chevrolet          chevrolet   5151
# dodge                  dodge   5572
# honda                  honda   5399
# isuzu                  isuzu   6785
# jaguar                jaguar  32250
# mazda                  mazda   5195
# mercedes-benz  mercedes-benz  25552
# mercury              mercury  16503
# mitsubishi        mitsubishi   5389
# nissan                nissan   5499
# peugot                peugot  11900
# plymouth            plymouth   5572
# porsche              porsche  22018
# saab                    saab  11850
# subaru                subaru   5118
# ...

# %%
company = df.groupby('make')
priceDf = company['make','price'].describe()
priceDf
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3024\4288321696.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = company['make','price'].describe()
#               price                                                         \
#               count          mean          std      min       25%      50%
# make
# alfa-romero     3.0  15498.333333  1734.937559  13495.0  14997.50  16500.0
# audi            6.0  17859.166667  3452.379493  13950.0  15800.00  17580.0
# bmw             8.0  26118.750000  9263.832033  16430.0  19958.75  22835.0
# chevrolet       3.0   6007.000000   754.421633   5151.0   5723.00   6295.0
# dodge           8.0   7790.125000  2350.334471   5572.0   6340.00   7150.5
# honda          13.0   8184.692308  2061.672112   5399.0   6855.00   7295.0
# isuzu           2.0   8916.500000  3014.396208   6785.0   7850.75   8916.5
# ...

# %%
company = df.groupby('make')
priceDf = company['make' , 'price'].describe().min()
priceDf
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3024\2103850542.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = company['make' , 'price'].describe().min()
# price  count       1.000000
#        mean     6007.000000
#        std       754.421633
#        min      5118.000000
#        25%      5723.000000
#        50%      6295.000000
#        75%      6435.000000
#        max      6575.000000
# dtype: float64

# %% [markdown]
# company = df.groupby('make')
# priceDf = company['make','price'].describe(). min()
# priceDf

# %%
company = df.groupby('make')
priceDf = company['make' , 'price'].describe().min()
priceDf
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3024\2103850542.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = company['make' , 'price'].describe().min()
# price  count       1.000000
#        mean     6007.000000
#        std       754.421633
#        min      5118.000000
#        25%      5723.000000
#        50%      6295.000000
#        75%      6435.000000
#        max      6575.000000
# dtype: float64

# %%
company = df.groupby('make')
priceDf = company['make' , 'price'].decribe().min()
priceDf
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3024\1520178399.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   priceDf = company['make' , 'price'].decribe().min()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3024\1520178399.py in <module>
#       1 company = df.groupby('make')
# ----> 2 priceDf = company['make' , 'price'].decribe().min()
#       3 priceDf
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'decribe'
